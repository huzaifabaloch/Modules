# %% [markdown]
# # Loading Data into Pandas

# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Reading Data into Pandas

# %%
#Read headers
df.columns

# Read each column
df['Name'].head()
df.Name[0:3]
df[['Name', 'Type 1']]

# Read each row
df.iloc[1:3]
df.iloc[1]
#for index, row in df.iterrows():
#    print(index, row['Name'])
df.loc[df['Type 1'] == 'Fire'][:2]

# Read a specific location (R, C)
#df.iloc[2, 1]

# %% [markdown]
# # Sorting/Describing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# Sorting single column ASC and DESC
df.sort_values('Name', ascending=True)[:5]
df.sort_values('Name', ascending=False)[:5]
# Out:
#        #              Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718  Zygarde50% Forme  Dragon  Ground  108     100      121       81
# 695  634          Zweilous    Dark  Dragon   72      85       70       65
# 46    41             Zubat  Poison  Flying   40      45       35       30
# 631  570             Zorua    Dark     NaN   40      65       40       80
# 632  571           Zoroark    Dark     NaN   60     105       60      120
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# 695       70     58           5      False
# 46        40     55           1      False
# 631       40     65           5      False
# 632       60    105           5      False

# %%
# Sorting multiple columns 1 -> asc, 2 -> desc
df.sort_values(['Type 1', 'HP']).head()
df.sort_values(['Type 1', 'HP'], ascending=[1, 0]).head()
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520      116       56     95           4      False
# 698      135      105    100           5      False
# 231       40       95     85           2      False
# 232       40      105     75           2      False
# 678      100       60    145           5      False

# %% [markdown]
# # Making changes to the data

# %%
# Making a new column that is the sum of all columns, just to get the statistic of each pokemon.
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head()
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405

# %%
# Verifying
45+49+49+65+65+45
# Out:
# 318

# %%
# reseting the dataframe
df = df.drop(columns=['Total'])

# %%
# Second way
# iloc [select_all_rows, number_of_columns].sum(horizontally)
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# reordering columns
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary  Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False    318  45
# 1  2                Ivysaur  Grass  Poison           1      False    405  60
# 2  3               Venusaur  Grass  Poison           1      False    525  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False    625  80
# 4  4             Charmander   Fire     NaN           1      False    309  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %% [markdown]
# # Saving our data (EXPORTING INTO DESIRED FORMAT)

# %%
df.to_csv('modified_pokemon_data.csv', index=False)

# %%
df.to_excel('modified_pokemon_data.xlsx', index=False)

# %%
df.to_csv('modified_pokemon_data.txt', sep='\t', index=False)
